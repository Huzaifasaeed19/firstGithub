# %% [markdown]
# # Jypter NoteBook in VS Code
# This is Much better then other jypter notebook

# %%
print("Python ka Chilla with Baba Ammar")

# %%
huzaifa = "My Name is Huzaifa"
huzaifa

# %%
import numpy as np
x = np.array([1,2,5,6,7,8,9,5])
x

# %%
import numpy as np  
import pandas as pd  
import matplotlib.pyplot as plt  
  
phool = pd.read_csv("iris.csv")

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
phool = pd.read_csv("iris.csv") 

plt.plot(phool.Id, phool["sepal.length"], "r--") 
plt.show

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)
