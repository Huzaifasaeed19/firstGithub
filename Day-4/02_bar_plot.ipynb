# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

phool = sns.load_dataset("iris")

#Draw a Bar Plot

sns.barplot(data=phool, x="species" , y="sepal_width")

plt.show()

# %%
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

phool = sns.load_dataset("iris")

#Draw a Bar Plot

sns.barplot(data=phool, x="species" , y="sepal_length")

plt.show()

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="sex" , y="alone", hue="who")

plt.show()

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"))

plt.show()

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red")

plt.show()
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\813150289.py:12: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red")

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red", ci=None)

plt.show()
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\116067592.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red", ci=None)
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\116067592.py:12: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:red'` for the same effect.
#
#   sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red", ci=None)

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red", ci=None , palette="pastel")

plt.show()
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\1993405713.py:12: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=titanic, x="sex" , y="alone", hue="who", order=("female","male"), color="red", ci=None , palette="pastel")

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 
import numpy 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="class" , y="fare", hue="sex", estimator="mean", ci=None)

plt.show()
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\3969798917.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=titanic, x="class" , y="fare", hue="sex", estimator="mean", ci=None)

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 
import numpy 

#loading DataSet

titanic = sns.load_dataset("titanic")

#Draw a Bar Plot

sns.barplot(data=titanic, x="class" , y="fare", hue="sex", estimator="median", ci=None)

plt.show()
# Out:
# C:\Users\huzai\AppData\Local\Temp\ipykernel_11656\1629977825.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=titanic, x="class" , y="fare", hue="sex", estimator="median", ci=None)

# %%
#importing libraries

import seaborn as sns
import matplotlib.pyplot as plt 
import numpy 

#loading DataSet

titanic = sns.load_dataset("titanic")
plt.figure(figsize=(4,2))

#Draw a Bar Plot

sns.barplot(data=titanic, x="class" , y="fare", hue="sex", estimator="mean", saturation=1)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from numpy import mean

titanic = sns.load_dataset("titanic")

titanic

sns.barplot(x="fare",y="class",hue="sex",data=titanic,estimator = mean , saturation=1)
# Out:
# <Axes: xlabel='fare', ylabel='class'>

# %%
#import Libraries
import seaborn as sns
import matplotlib.pyplot as plt

#load dataset
titanic=sns.load_dataset("titanic")

sns.barplot(x="class",y="fare" , data=titanic , linewidth= 3 , errcolor = "0.5" , edgecolor=" 0.3", facecolor=(1,1,1,0))

#facecolor=(r,g,b,alpha)
# Out:
# C:\Users\kk\AppData\Local\Temp\ipykernel_22956\3465492644.py:8: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '0.5'}` instead.
#
#   sns.barplot(x="class",y="fare" , data=titanic , linewidth= 3 , errcolor = "0.5" , edgecolor=" 0.3", facecolor=(1,1,1,0))
# <Axes: xlabel='class', ylabel='fare'>
